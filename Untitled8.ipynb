# %% [markdown]
# <a href="https://colab.research.google.com/github/sudheerachl/chatbot/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_json('../input/mental-health-conversational-data/intents.json', encoding='ISO-8859-2')
df.head()

# %%
from IPython.display import update_display
update_display(None, display_id='update_display')
update_display({'application/vnd.vegalite.v4+json': 104857600000}, display_id='update_display')
#increasing the input size for visualization of jason file
# Out:
# {'application/vnd.vegalite.v4+json': 104857600000}

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#training datase
import random
import json
import pickle
import numpy as np
import pandas as pd
# !pip install keras==2.11.0
# !pip install tensorflow==2.11.*
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers.legacy import SGD
from tensorflow.keras.models import load_model #testing purpose alone
lemmatizer=WordNetLemmatizer()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras==2.11.0 in /usr/local/lib/python3.9/dist-packages (2.11.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow==2.11.* in /usr/local/lib/python3.9/dist-packages (2.11.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (2.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (67.6.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (23.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (4.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (2.11.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (0.32.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.14.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.22.4)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (23.3.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (16.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (3.8.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (1.53.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow==2.11.*) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow==2.11.*) (0.40.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2.27.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (3.4.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2.17.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.12,>=2.11->tensorflow==2.11.*) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (6.1.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow==2.11.*) (3.2.2)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import json
with open('/content/gdrive/MyDrive/jokes.JSON') as f:
    intents = json.load(f)
#preprocessing dataset using nltk
words=[]
classes=[]
documents=[]
ignore_letters=['?','!','.',',']#punctuations are ignored
for intent in intents['intents']:
  for pattern in intent['patterns']:
    word_list=nltk.word_tokenize(pattern)
    words.extend(word_list)
    documents.append((word_list,intent['tag']))
    if intent['tag'] not in classes:
      classes.append(intent['tag'])
words =[lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]#converts tto natural form like helping to help
words = sorted(set(words))
classes=sorted(set(classes))
pickle.dump(words,open('/content/gdrive/MyDrive/words.pkl','wb'))#converted tto byte stream.
pickle.dump(classes,open('/content/gdrive/MyDrive/classes.pkl','wb'))

training=[]
output_empty=[0]*len(classes)#create a list of 0,s length=number classes in dataset.

for document in documents:
  bag=[]
  word_patterns=document[0]
  words = [lemmatizer.lemmatize(word) for word in words if word and word not in ignore_letters]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)

  output_row=list(output_empty)#copy of output_empty
  output_row[classes.index(document[1])]=1
  training.append([bag,output_row])

random.shuffle(training)
training=np.array(training)

train_x=list(training[:,0])
train_y=list(training[:,1])
model=Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))


sgd=SGD(learning_rate=0.01,decay=1e-6,momentum=0.9,nesterov=True)#stochiastic graient descen- to control loss function uring training
model.compile(loss='categorical_crossentropy',optimizer=sgd,metrics=['accuracy'])
hist = model.fit(np.array(train_x),np.array(train_y),epochs=200,batch_size=5,verbose=1)#epoch -number of times training iterates over data seta in batches
model.save('/content/gdrive/MyDrive/chatbotmodel.h5', hist)
print('Training Done')
# Out:
# Mounted at /content/gdrive
# <ipython-input-2-ea4b3b49bb60>:39: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training=np.array(training)
# Epoch 1/200
# 88/88 [==============================] - 1s 2ms/step - loss: 4.7036 - accuracy: 0.0206
# Epoch 2/200
# 88/88 [==============================] - 0s 2ms/step - loss: 4.6008 - accuracy: 0.0275
# Epoch 3/200
# 88/88 [==============================] - 0s 2ms/step - loss: 4.5216 - accuracy: 0.0481
# Epoch 4/200
# 88/88 [==============================] - 0s 1ms/step - loss: 4.4307 - accuracy: 0.0366
# Epoch 5/200
200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6875 - accuracy: 0.7849
# Epoch 109/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7667 - accuracy: 0.7735
# Epoch 110/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6924 - accuracy: 0.7941
# Epoch 111/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.8394 - accuracy: 0.7643
# Epoch 112/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7710 - accuracy: 0.7735
# Epoch 113/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6793 - accuracy: 0.7986
# Epoch 114/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7336 - accuracy: 0.7780
# Epoch 115/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6570 - accuracy: 0.7963
# Epoch 116/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7475 - accuracy: 0.7826
# Epoch 117/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8359 - accuracy: 0.7712
# Epoch 118/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7335 - accuracy: 0.7735
# Epoch 119/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7588 - accuracy: 0.7918
# Epoch 120/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7027 - accuracy: 0.7986
# Epoch 121/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6424 - accuracy: 0.8055
# Epoch 122/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7622 - accuracy: 0.7483
# Epoch 123/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7277 - accuracy: 0.7757
# Epoch 124/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7988 - accuracy: 0.7529
# Epoch 125/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6835 - accuracy: 0.7826
# Epoch 126/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7643 - accuracy: 0.7735
# Epoch 127/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7376 - accuracy: 0.7643
# Epoch 128/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6075 - accuracy: 0.8284
# Epoch 129/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7642 - accuracy: 0.7689
# Epoch 130/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8768 - accuracy: 0.7551
# Epoch 131/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6749 - accuracy: 0.7918
# Epoch 132/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7367 - accuracy: 0.7803
# Epoch 133/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7833 - accuracy: 0.7643
# Epoch 134/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.8426 - accuracy: 0.7529
# Epoch 135/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7315 - accuracy: 0.7551
# Epoch 136/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8513 - accuracy: 0.7483
# Epoch 137/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7622 - accuracy: 0.7666
# Epoch 138/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7332 - accuracy: 0.7780
# Epoch 139/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.8241 - accuracy: 0.7757
# Epoch 140/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7095 - accuracy: 0.7941
# Epoch 141/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7688 - accuracy: 0.7620
# Epoch 142/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6893 - accuracy: 0.7712
# Epoch 143/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8195 - accuracy: 0.7620
# Epoch 144/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6556 - accuracy: 0.8009
# Epoch 145/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6645 - accuracy: 0.7803
# Epoch 146/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6337 - accuracy: 0.8078
# Epoch 147/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7037 - accuracy: 0.7986
# Epoch 148/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7239 - accuracy: 0.7803
# Epoch 149/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7365 - accuracy: 0.7872
# Epoch 150/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6519 - accuracy: 0.8032
# Epoch 151/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6889 - accuracy: 0.8055
# Epoch 152/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7611 - accuracy: 0.7643
# Epoch 153/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7538 - accuracy: 0.7620
# Epoch 154/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7366 - accuracy: 0.7872
# Epoch 155/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.7750 - accuracy: 0.7872
# Epoch 156/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7679 - accuracy: 0.7574
# Epoch 157/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7405 - accuracy: 0.7597
# Epoch 158/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7737 - accuracy: 0.7780
# Epoch 159/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.5951 - accuracy: 0.8284
# Epoch 160/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8139 - accuracy: 0.7780
# Epoch 161/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7536 - accuracy: 0.7826
# Epoch 162/200
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7373 - accuracy: 0.7918
# Epoch 163/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.7986
# Epoch 164/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.7849
# Epoch 165/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7199 - accuracy: 0.7941
# Epoch 166/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6800 - accuracy: 0.7849
# Epoch 167/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7262 - accuracy: 0.7941
# Epoch 168/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.8009
# Epoch 169/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7161 - accuracy: 0.7986
# Epoch 170/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7295 - accuracy: 0.7735
# Epoch 171/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6009 - accuracy: 0.8169
# Epoch 172/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7961 - accuracy: 0.7574
# Epoch 173/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8228 - accuracy: 0.7803
# Epoch 174/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7975 - accuracy: 0.7506
# Epoch 175/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8061 - accuracy: 0.7597
# Epoch 176/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6211 - accuracy: 0.8009
# Epoch 177/200
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7237 - accuracy: 0.7735
# Epoch 178/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6742 - accuracy: 0.7963
# Epoch 179/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6395 - accuracy: 0.7986
# Epoch 180/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6666 - accuracy: 0.8215
# Epoch 181/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7898 - accuracy: 0.7986
# Epoch 182/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7027 - accuracy: 0.7872
# Epoch 183/200
# 88/88 [==============================] - 0s 3ms/step - loss: 0.7688 - accuracy: 0.7872
# Epoch 184/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8156 - accuracy: 0.7757
# Epoch 185/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7105 - accuracy: 0.7986
# Epoch 186/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6480 - accuracy: 0.8146
# Epoch 187/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7386 - accuracy: 0.8009
# Epoch 188/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7575 - accuracy: 0.7780
# Epoch 189/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8238 - accuracy: 0.7597
# Epoch 190/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7411 - accuracy: 0.7757
# Epoch 191/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6355 - accuracy: 0.8124
# Epoch 192/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7333 - accuracy: 0.7963
# Epoch 193/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6400 - accuracy: 0.8009
# Epoch 194/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6209 - accuracy: 0.8032
# Epoch 195/200
# 88/88 [==============================] - 0s 1ms/step - loss: 0.6997 - accuracy: 0.7986
# Epoch 196/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8122 - accuracy: 0.7666
# Epoch 197/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.8017 - accuracy: 0.7666
# Epoch 198/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6037 - accuracy: 0.8032
# Epoch 199/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.6614 - accuracy: 0.7918
# Epoch 200/200
# 88/88 [==============================] - 0s 2ms/step - loss: 0.7643 - accuracy: 0.7757
# Training Done
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea4b3b49bb60> in <cell line: 56>()
#      54 model.save('/content/gdrive/MyDrive/chatbotmodel.h5', hist)
#      55 print('Training Done')
# ---> 56 plot_model(model, show_shapes=True, show_layer_names=True)
#      57 plt.show()
#      58
#
# NameError: name 'plot_model' is not defined

# %%
import matplotlib.pyplot as plt
#loss grpah
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.show()

# Plot the accuracy graph
plt.plot(hist.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()

# %%
# testing
with open('/content/gdrive/MyDrive/jokes.JSON') as json_file:
    intents = json.load(json_file)

words=pickle.load(open('/content/gdrive/MyDrive/words.pkl','rb'))
classes=pickle.load(open('/content/gdrive/MyDrive/classes.pkl','rb'))
model=load_model('/content/gdrive/MyDrive/chatbotmodel.h5')

def clean_up_sentence(sentence):
  sentence_words=nltk.word_tokenize(sentence)
  sentence_words=[lemmatizer.lemmatize(word) for word in sentence_words]
  return sentence_words
def bag_of_words(sentence):
  sentence_words=clean_up_sentence(sentence)
  bag=[0]*len(words)
  for w in sentence_words:
    for i,word in enumerate(words):
      if word == w:
        bag[i]=1
  return np.array(bag)

def predict_class(sentence):
  bow=bag_of_words(sentence)
  res=model.predict(np.array([bow]))[0]
  ERROR_THRESHOLD=0.25
  results=[[i,r] for i,r in enumerate(res) if r> ERROR_THRESHOLD]

  results.sort(key=lambda x:x[1],reverse=True)
  return_list=[]
  for r in results:
    return_list.append({'intent': classes[r[0]],'probability':str(r[1])})
  return return_list
def get_response(intents_list,intents_json):
  tag=intents_list[0]['intent']
  list_of_intents=intents_json['intents']
  for i in list_of_intents:
    if i['tag']==tag:
      result=random.choice(i['responses'])
      break
  return result

print("Hi \nhow,may i help you.")
while True:
  message = input("")
  if message == "bye":
    ints = predict_class(message)
    print(get_response(ints, intents))
    break
  else:
    ints = predict_class(message)
    if len(ints) > 0:
      print(get_response(ints, intents))
    else:
      print("I'm sorry, I don't understand. Can you please rephrase your question?")
# Out:
# Hi
# how,may i help you.
# cold.
# 1/1 [==============================] - 0s 74ms/step
# medicines you can consume : Dextromethorphan,Decongestant,Diphenhydramine,Crocin Cold & Flu Max, preventions that you must follow :Wash your hands,Avoid touching your face,Clean frequently used surfaces,Use hand sanitizers,SUGGESTED FOODS ARE:Garlic,Vitamin C–containing fruits,Leafy greens,Broccoli,Oatmeal,Spices,Chicken Soup
# depression
# 1/1 [==============================] - 0s 19ms/step
# medicines you can consume :  brexpiprazole, quetiapine,olanzapine, prevention that you must follow :Exercise regularly,Cut back on social media time,Drink Water as Your Primary Beverage,Build strong relationships,Minimize your daily choices, Follow a Very-Low-Carb Diet,SUGGESTED FOODS ARE:Get Enough Vitamin D,Include Omega-3 Fatty Acids,Beans and legumes
# hi
# 1/1 [==============================] - 0s 28ms/step
# what can i do for you?
# who are you?
# 1/1 [==============================] - 0s 20ms/step
# That's a great name. Tell me more about yourself.
# i feel sad
# 1/1 [==============================] - 0s 18ms/step
# Why do you think you feel this way?
# difference between sad and depression.
# 1/1 [==============================] - 0s 26ms/step
# Sadness is a normal reaction to a loss, disappointment, problems, or other difficult situations. Feeling sad from time to time is just another part of being human. In these cases, feelings of sadness go away quickly and you can go about your daily life. Other ways to talk about sadness might be feeling low, feeling down, or feeling blue.A person may say they are feeling depressed, but if it goes away on its own and doesn't impact life in a big way, it probably isn't the illness of depression. Depression is a mental illness that affects your mood, the way you understand yourself, and the way you understand and relate to things around you. It can also go by different names, such as clinical depression, major depressive disorder, or major depression. Depression can come up for no reason, and it lasts for a long time. It's much more than sadness or low mood. People who experience depression may feel worthless or hopeless. They may feel unreasonable guilty. Some people may experience depression as anger or irritability. It may be hard to concentrate or make decisions. Most people lose interest in things that they used to enjoy and may isolate themselves from others. There are also physical signs of depression, such as problems with sleep, appetite and energy and unexplainable aches or pains. Some may experience difficult thoughts about death or ending their life (suicide). Depression lasts longer than two weeks, doesn't usually go away on its own, and impacts your life. It's a real illness, and it is very treatable. It's important to seek help if you're concerned about depression.
# mental health
# 1/1 [==============================] - 0s 19ms/step
# Challenges or problems with your mental health can arise from psychological, biological, and social, issues, as well as life events.
# tell me a joke
# 1/1 [==============================] - 0s 19ms/step
# Why can't Barbie get pregnant? Because Ken comes in a different box. Heyooooooo
# joke.
# 1/1 [==============================] - 0s 24ms/step
# What's the difference between an illegal Mexican and an autonomous robot...? Nothing... they were both made to steal American jobs.
# i am angry
# 1/1 [==============================] - 0s 30ms/step
# Can you elaborate on that?
# u are stupid.
# 1/1 [==============================] - 0s 18ms/step
# I wish you wouldn't say such hurtful things. I'm sorry if I wasn't useful
# bye.
# 1/1 [==============================] - 0s 31ms/step
# Bye! Come back again.
# bye
# 1/1 [==============================] - 0s 23ms/step
# I'll see you soon.

# %%
#jokes-https://www.kaggle.com/datasets/abhinavmoudgil95/short-jokes
#https://storage.googleapis.com/kagglesdsdata/datasets/2594075/4429121/intents.json?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230405%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230405T082453Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
#https://raw.githubusercontent.com/amberkakkar01/Health-Care-Chatbot/main/intents.json

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# Define the neural network architecture
input_layer = "Input Layer (128 nodes)"
flatten_layer = "Flatten Layer"
dropout1 = "Dropout (0.5)"
hidden_layer = "Hidden Layer (64 nodes, ReLU)"
dropout2 = "Dropout (0.5)"
output_layer = "Output Layer (softmax)"
model=Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))

# %%
# Plot the neural network diagram
plot_model(model, show_shapes=True, show_layer_names=True)
plt.show()
plt.savefig('neural_network_diagram.png')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import plot_model

# Define the neural network architecture
input_layer = "Input Layer (128 nodes)"
flatten_layer = "Flatten Layer"
dropout1 = "Dropout (0.5)"
hidden_layer = "Hidden Layer (64 nodes, ReLU)"
dropout2 = "Dropout (0.5)"
output_layer = "Output Layer (softmax)"

# Create a sequential model
model=Sequential()
model.add(Dense(128,input_shape=(len(train_x[0]),),activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax'))
# Plot the neural network diagram
plot_model(model, to_file='neural_network_diagram.png', show_shapes=True, show_layer_names=True)

# Load the image and display it
img = plt.imread('neural_network_diagram.png')
plt.imshow(img)
plt.axis('off')
plt.show()
